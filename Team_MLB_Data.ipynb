# %% [markdown]
# <a href="https://colab.research.google.com/github/Redsoxnc87/Hello-World/blob/master/Team_MLB_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import math 
import numpy as np 
import requests 
import os 
import sys

# %%
import operator
import pandas.plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
indians = pd.read_html('https://www.fangraphs.com/teams/indians')

# %%
AL_Central = pd.DataFrame(indians[10])

# %%
indians_offense = pd.DataFrame(indians[11])

# %%
indians_pitching = pd.DataFrame(indians[12])

# %%
whitesox = pd.read_html('https://www.fangraphs.com/teams/whitesox')

# %%
whitesox_offense = pd.DataFrame(whitesox[11])

# %%
whitesox_pitching = pd.DataFrame(whitesox[12])

# %%
astros = pd.read_html('https://www.fangraphs.com/teams/astros')

# %%
astros_offense = pd.DataFrame(astros[11])

# %%
astros_pitching = pd.DataFrame(astros[12])

# %%
athletics = pd.read_html('https://www.fangraphs.com/teams/athletics')

# %%
athletics_offense = pd.DataFrame(athletics[11])

# %%
athletics_pitching = pd.DataFrame(athletics[12])

# %%
angels = pd.read_html('https://www.fangraphs.com/teams/angels')

# %%
angels_offense = pd.DataFrame(angels[11])

# %%
angels_offense = pd.DataFrame(angels[12])

# %%
rangers = pd.read_html('https://www.fangraphs.com/teams/rangers')

# %%
rangers_offense = pd.DataFrame(rangers[11])

# %%
rangers_pitching = pd.DataFrame(rangers[12])

# %%
reds = pd.read_html('https://www.fangraphs.com/teams/reds')

# %%
reds_offense = pd.DataFrame(reds[11])

# %%
reds_pitching = pd.DataFrame(reds[12])

# %%
brewers = pd.read_html('https://www.fangraphs.com/teams/brewers')

# %%
brewers_offense = pd.DataFrame(brewers[11])

# %%
brewers_pitching = pd.DataFrame(brewers[12])

# %%
rockies = pd.read_html('https://www.fangraphs.com/teams/rockies')

# %%
rockies_offense = pd.DataFrame(rockies[11])

# %%
rockies_pitching = pd.DataFrame(rockies[12])

# %%
mariners = pd.read_html('https://www.fangraphs.com/teams/mariners')

# %%
mariners_offense = pd.DataFrame(mariners[11])

# %%
mariners_pitching = pd.DataFrame(mariners[12])

# %%
tigers = pd.read_html('https://www.fangraphs.com/teams/tigers')

# %%
tigers_offense = pd.DataFrame(tigers[11])

# %%
tigers_pitching = pd.DataFrame(tigers[12])

# %%
pirates = pd.read_html('https://www.fangraphs.com/teams/pirates')

# %%
pirates_offense = pd.DataFrame(pirates[11])

# %%
pirates_pitching = pd.DataFrame(pirates[12])

# %%
orioles = pd.read_html('https://www.fangraphs.com/teams/orioles')

# %%
orioles_offense = pd.DataFrame(orioles[11])

# %%
orioles_pitching = pd.DataFrame(orioles[12])

# %%
nationals = pd.read_html('https://www.fangraphs.com/teams/nationals')

# %%
nationals_offense = pd.DataFrame(nationals[11])

# %%
nationals_pitching = pd.DataFrame(nationals[12])

# %%
twins = pd.read_html('https://www.fangraphs.com/teams/twins')

# %%
twins_offense = pd.DataFrame(twins[11])

# %%
twins_pitching = pd.DataFrame(twins[12])

# %%
royals = pd.read_html('https://www.fangraphs.com/teams/royals')

# %%
royals_offense = pd.DataFrame(royals[11])

# %%
royals_pitching = pd.DataFrame(royals[12])

# %%
dbacks = pd.read_html('https://www.fangraphs.com/teams/diamondbacks')

# %%
dbacks_offense = pd.DataFrame(dbacks[11])

# %%
dbacks_pitching = pd.DataFrame(dbacks[12])

# %%
padres = pd.read_html('https://www.fangraphs.com/teams/padres')

# %%
padres_offense = pd.DataFrame(padres[11])

# %%
padres_pitching = pd.DataFrame(padres[12])

# %%
giants = pd.read_html('https://www.fangraphs.com/teams/giants')

# %%
giants_offense = pd.DataFrame(giants[11])

# %%
giants_pitching = pd.DataFrame(giants[12])

# %%
dodgers = pd.read_html('https://www.fangraphs.com/teams/dodgers')

# %%
dodgers_offense = pd.DataFrame(dodgers[11])

# %%
dodgers_pitching = pd.DataFrame(dodgers[12])

# %%
Zach_Plesac = indians_pitching.iloc[2,0:]

# %%
type(Zach_Plesac)
# Out:
# pandas.core.series.Series

# %%
Zach_Plesac
# Out:
# Name     Zach Plesac
# Age               25
# G                  2
# GS                 2
# IP                15
# K%             32.1%
# BB%             1.9%
# HR/9             1.2
# BABIP          0.152
# LOB%           96.2%
# GB%            37.1%
# HR/FB          14.3%
# ERA              1.8
# FIP             2.66
# xFIP            2.61
# WAR              0.5
# Name: 2, dtype: object

# %%
whitesox_pitching.head(9)
# Out:
#              Name  Age  G  GS    IP     K%  ...    GB%  HR/FB   ERA   FIP  xFIP  WAR
# 0  Dallas Keuchel   32  3   3  17.2  15.5%  ...  56.9%   7.7%  2.55  2.83  3.41  0.5
# 1   Evan Marshall   30  7   0   7.0  37.0%  ...  42.9%   0.0%  0.00  1.43  2.20  0.3
# 2     Alex Colome   31  6   0   6.0  20.8%  ...  64.7%   0.0%  0.00  1.83  2.73  0.3
# 3    Aaron Bummer   26  7   0   7.1  40.0%  ...  78.6%   0.0%  1.23  1.36  1.61  0.3
# 4   Ross Detwiler   34  5   0   8.1  26.9%  ...  68.4%   0.0%  0.00  1.32  2.40  0.2
# 5     Matt Foster   25  3   0   3.2  42.9%  ...  14.3%   0.0%  0.00  0.54  2.01  0.2
# 6      Codi Heuer   23  4   0   5.1  36.8%  ...  50.0%   0.0%  1.69  0.37  1.38  0.2
# 7   Lucas Giolito   25  3   3  15.2  27.7%  ...  44.7%  25.0%  5.17  4.72  3.61  0.1
# 8   Jimmy Cordero   28  6   0   4.1  21.1%  ...  50.0%   0.0%  4.15  3.23  4.47  0.1
#
# [9 rows x 16 columns]

# %%
Matt_Foster = whitesox_pitching.iloc[5,0:]

# %%
Framber_Valdez = astros_pitching.iloc[3,0:]

# %%
athletics_pitching.head()
# Out:
#              Name  Age  G  GS    IP     K%  ...    GB%  HR/FB   ERA   FIP  xFIP  WAR
# 0   Chris Bassitt   31  3   3  16.2  23.1%  ...  31.1%   0.0%  1.08  2.10  4.15  0.6
# 1    Joakim Soria   36  7   0   7.2  41.9%  ...  37.5%   0.0%  0.00  0.39  2.26  0.5
# 2  Frankie Montas   27  3   3  16.0  25.0%  ...  41.5%   0.0%  2.25  2.75  4.32  0.5
# 3   Jesus Luzardo   22  3   1  11.2  26.1%  ...  55.6%   0.0%  2.31  2.23  3.00  0.3
# 4     Burch Smith   30  4   0   7.1  23.1%  ...  36.8%   0.0%  0.00  1.77  3.73  0.3
#
# [5 rows x 16 columns]

# %%
Frankie_Montas = athletics_pitching.iloc[2,0:]

# %%
rangers_pitching.head()
# Out:
#                  Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0          Lance Lynn   33  3   3  18.1  ...   5.9%  0.49  2.56  3.52  0.7
# 1  Jonathan Hernandez   23  6   0   8.0  ...   0.0%  2.25  1.62  3.64  0.4
# 2          Mike Minor   32  3   3  15.2  ...  10.0%  6.89  3.70  4.33  0.3
# 3        Kolby Allard   22  1   1   4.0  ...   0.0%  2.25  3.00  5.69  0.1
# 4      Rafael Montero   29  1   0   1.0  ...   0.0%  0.00 -1.00 -1.00  0.1
#
# [5 rows x 16 columns]

# %%
Kolby_Allard = rangers_pitching.iloc[3,0:]

# %%
reds_pitching.head(12)
# Out:
#                   Name  Age  G  GS    IP  ...  HR/FB    ERA   FIP  xFIP  WAR
# 0         Trevor Bauer   29  3   3  19.1  ...  13.3%   0.93  1.81  1.86  0.8
# 1        Luis Castillo   27  3   3  17.0  ...   9.1%   4.76  1.76  2.16  0.8
# 2           Sonny Gray   30  3   3  18.2  ...  28.6%   0.96  2.35  1.64  0.7
# 3          Tyler Mahle   25  2   2  10.0  ...   0.0%   1.80  2.20  4.71  0.4
# 4   Anthony DeSclafani   30  1   1   5.0  ...   0.0%   0.00  2.20  3.63  0.2
# 5      Raisel Iglesias   30  4   0   4.1  ...  20.0%   6.23  2.31  1.38  0.2
# 6           Lucas Sims   26  7   0   7.1  ...  12.5%   1.23  3.95  4.14  0.1
# 7         Tejay Antone   26  2   1   8.2  ...  14.3%   2.08  4.50  4.45  0.1
# 8         Amir Garrett   28  5   0   4.2  ...  25.0%   1.93  4.07  2.82  0.1
# 9        Matt Davidson   29  1   0   1.0  ...   0.0%   0.00  1.00  2.79  0.0
# 10        Brooks Raley   32  4   0   4.0  ...   0.0%   9.00  3.75  5.09  0.0
# ...

# %%
Anthony_Desclafani = reds_pitching.iloc[4,0:]

# %%
brewers_pitching.head(12)
# Out:
#                 Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0   Brandon Woodruff   27  3   3  17.1  ...  18.2%  2.08  2.77  2.41  0.6
# 1       David Phelps   33  5   0   5.2  ...   0.0%  1.59  1.59  2.22  0.2
# 2     Freddy Peralta   24  2   1   6.0  ...   0.0%  6.00  2.50  4.29  0.2
# 3      Josh Lindblom   33  2   2   8.2  ...  16.7%  4.15  3.11  2.86  0.2
# 4         Josh Hader   26  3   0   3.0  ...   0.0%  0.00  2.00  4.39  0.2
# 5      Adrian Houser   27  2   2  12.0  ...  20.0%  0.75  4.08  3.75  0.1
# 6     Brett Anderson   32  1   1   3.0  ...   0.0%  6.00  2.66  4.46  0.1
# 7      Corbin Burnes   25  2   1   7.0  ...  20.0%  3.86  4.28  3.71  0.1
# 8        Brent Suter   30  3   0   6.1  ...  20.0%  5.68  3.47  2.84  0.1
# 9       Alex Claudio   28  3   0   3.1  ...   0.0%  2.70  2.10  3.18  0.1
# 10      Eric Yardley   29  6   0   5.2  ...   0.0%  0.00  2.64  2.96  0.1
# 11    Devin Williams   25  4   0   4.1  ...  20.0%  2.08  5.07  4.15  0.0
#
# ...

# %%
Brett_Anderson = brewers_pitching.iloc[6,0:]

# %%
mariners_pitching.head(16)
# Out:
#                  Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP   xFIP  WAR
# 0       Yusei Kikuchi   29  3   3  15.1  ...   0.0%  5.28  2.08   2.79  0.5
# 1      Marco Gonzales   28  3   3  17.2  ...  16.7%  3.06  4.58   4.08  0.2
# 2    Carl Edwards Jr.   28  5   0   4.2  ...   0.0%  1.93  1.07   2.61  0.2
# 3    Justus Sheffield   24  2   2   7.2  ...   0.0%  9.39  3.52   4.93  0.1
# 4         Matt Magill   30  4   0   4.0  ...   0.0%  0.00  2.75   4.54  0.1
# 5      Taijuan Walker   27  3   3  14.0  ...  11.1%  5.79  4.85   5.31  0.1
# 6     Taylor Guilbeau   27  3   0   3.0  ...   0.0%  3.00  3.33   5.13  0.0
# 7         Joey Gerber   23  2   0   2.1  ...   0.0%  0.00  4.28   5.82  0.0
# 8       Dan Altavilla   27  5   0   5.0  ...  11.1%  5.40  4.60   5.23  0.0
# 9   Anthony Misiewicz   25  4   0   4.1  ...  33.3%  4.15  5.31   3.55  0.0
# 10   Kendall Graveman   29  2   2   8.2  ...  16.7%  8.31  5.42   4.91  0.0
# ...

# %%
Nick_Margevicius = mariners_pitching.iloc[13,0:]

# %%
tigers_pitching.head(15)
# Out:
#                 Name  Age  G  GS    IP  ...   HR/FB    ERA    FIP   xFIP  WAR
# 0   Spencer Turnbull   27  2   2  11.0  ...    0.0%   2.45   1.82   3.29  0.5
# 1       Jose Cisnero   31  6   0   6.2  ...    0.0%   2.70   1.80   3.41  0.3
# 2    Tyler Alexander   25  4   0   7.2  ...   33.3%   1.17   2.08   1.09  0.2
# 3       Gregory Soto   25  6   0   6.2  ...    0.0%   0.00   1.50   2.58  0.2
# 4     John Schreiber   26  4   0   4.2  ...    0.0%   0.00   2.14   4.07  0.1
# 5      Carson Fulmer   26  4   0   3.1  ...    0.0%   5.40   1.50   3.11  0.1
# 6        Buck Farmer   29  6   0   5.1  ...    0.0%   3.38   3.75   5.09  0.1
# 7       Bryan Garcia   25  5   0   4.1  ...    0.0%   4.15   3.92   6.41  0.0
# 8       Matthew Boyd   29  3   3  14.2  ...   16.7%   9.20   5.32   4.86  0.0
# 9    Kyle Funkhouser   26  2   0   2.0  ...    0.0%  22.50   4.00   5.79  0.0
# 10     Daniel Norris   27  1   1   1.2  ...    0.0%  10.80   6.60  10.91  0.0
# ...

# %%
Ivan_Nova = tigers_pitching.iloc[12,0:]

# %%
pirates_pitching.head(12)
# Out:
#                    Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0         Derek Holland   33  2   2  11.1  ...   9.1%  4.76  3.97  4.56  0.2
# 1        Chris Stratton   29  6   0   6.1  ...   0.0%  2.84  2.21  3.63  0.2
# 2             Chad Kuhl   27  3   1   9.0  ...  11.1%  2.00  2.78  3.13  0.2
# 3            Sam Howard   27  3   0   4.0  ...   0.0%  0.00  2.00  3.79  0.2
# 4         Steven Brault   28  3   2   5.0  ...   0.0%  7.20  4.00  5.08  0.2
# 5       Trevor Williams   28  3   3  15.1  ...  11.1%  3.52  4.43  4.85  0.2
# 6     Jonathan Brubaker   26  3   1   8.0  ...  12.5%  3.38  3.87  4.04  0.1
# 7     Richard Rodriguez   30  6   0   6.0  ...  12.5%  3.00  3.00  3.23  0.1
# 8   Dovydas Neverauskas   27  7   0   7.0  ...  33.3%  6.43  3.57  2.48  0.1
# 9            Nick Burdi   27  3   0   2.1  ...   0.0%  3.86  2.14  4.45  0.1
# 10         Robbie Erlin   29  2   0   3.1  ...   0.0%  5.40  2.40  5.63  0.0
# ...

# %%
Derek_Holland = pirates_pitching.iloc[0,0:]

# %%
orioles_pitching.head(18)
# Out:
#                    Name  Age   G  GS     IP  ...  HR/FB     ERA    FIP   xFIP  WAR
# 0          Tommy Milone   33   3   3   14.0  ...   6.3%    3.21   2.50   3.62  0.5
# 1         Miguel Castro   25   6   0    6.1  ...   0.0%    0.00   0.94   1.80  0.4
# 2         Travis Lakins   26   5   0    7.2  ...   0.0%    3.52   1.30   2.24  0.2
# 3             Alex Cobb   32   3   3   14.1  ...  28.6%    2.51   4.18   3.25  0.2
# 4       Shawn Armstrong   29   4   0    4.2  ...   0.0%    0.00   1.07   2.61  0.2
# 5         Mychal Givens   30   4   0    4.0  ...   0.0%    0.00   1.50   4.19  0.1
# 6        Richard Bleier   33   2   0    3.0  ...   0.0%    0.00   1.33   1.33  0.1
# 7         Evan Phillips   25   4   0    4.2  ...   0.0%    9.64   2.78   3.17  0.1
# 8          Tanner Scott   25   4   0    3.2  ...   0.0%    0.00   3.27   3.76  0.1
# 9            David Hess   26   2   0    5.0  ...   0.0%    5.40   3.80   5.95  0.0
# ...

# %%
Tom_Eshelman = orioles_pitching.iloc[16,0:]

# %%
nationals_pitching.head(12)
# Out:
#               Name  Age  G  GS    IP  ...  HR/FB    ERA   FIP  xFIP  WAR
# 0     Max Scherzer   35  3   3  13.2  ...  16.7%   3.29  2.49  2.32  0.4
# 1   Patrick Corbin   30  2   2  12.0  ...  20.0%   3.00  2.75  2.08  0.4
# 2    Daniel Hudson   33  4   0   4.2  ...   0.0%   0.00  0.64  2.18  0.3
# 3      Javy Guerra   34  4   0   5.2  ...  16.7%   1.59  3.17  2.78  0.1
# 4      Sam Freeman   33  5   0   4.0  ...   0.0%   0.00  3.00  4.79  0.1
# 5    Kyle Finnegan   28  3   0   3.2  ...   0.0%   0.00  2.45  3.43  0.1
# 6    Tanner Rainey   27  6   0   5.2  ...  10.0%   1.59  3.88  4.76  0.0
# 7      Ryne Harper   31  6   0   6.0  ...  20.0%   4.50  4.00  3.33  0.0
# 8     Wander Suero   28  2   0   2.0  ...   0.0%  13.50  4.50  7.19  0.0
# 9    James Bourque   26  2   0   1.1  ...   0.0%   0.00  5.25  6.59  0.0
# 10  Sean Doolittle   33  3   0   1.2  ...   0.0%  10.80  5.40  8.63  0.0
# 11     Austin Voth   28  1   1   5.0  ...  20.0%   3.60  7.40  5.79 -0.1
#
# ...

# %%
Austin_Voth = nationals_pitching.iloc[11,0:]

# %%
royals_pitching.head(2)
# Out:
#           Name  Age  G  GS    IP     K%  ...    GB%  HR/FB   ERA   FIP  xFIP  WAR
# 0  Danny Duffy   31  3   3  15.1  25.4%  ...  37.5%   6.3%  4.11  3.13  4.15  0.4
# 1  Brad Keller   24  1   1   5.0  35.0%  ...  54.5%   0.0%  0.00  1.40  2.12  0.3
#
# [2 rows x 16 columns]

# %%
Danny_Duffy = royals_pitching.iloc[0,0:]

# %%
dbacks_pitching.head(7)
# Out:
#               Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0   Archie Bradley   27  3   0   3.2  ...   0.0%  2.45  0.00  0.98  0.3
# 1    Merrill Kelly   31  2   2  13.2  ...  17.6%  2.63  4.46  3.84  0.2
# 2       Zac Gallen   24  3   3  16.0  ...  23.1%  2.81  4.31  3.33  0.2
# 3    Junior Guerra   35  6   0   5.2  ...   0.0%  0.00  2.64  3.28  0.1
# 4   Taylor Widener   25  3   0   5.2  ...   0.0%  0.00  3.17  4.12  0.0
# 5    Taylor Clarke   27  3   0   9.2  ...  16.7%  2.79  3.62  3.39  0.0
# 6  Stefan Crichton   28  7   0   5.0  ...  33.3%  3.60  3.60  2.08  0.0
#
# [7 rows x 16 columns]

# %%
Merrill_Kelly = dbacks_pitching.iloc[1,0:]

# %%
padres_pitching.head(5)
# Out:
#                Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0     Chris Paddack   24  3   3  17.0  ...  13.3%  2.65  2.94  2.99  0.4
# 1     Drew Pomeranz   31  7   0   6.1  ...   0.0%  0.00  1.26  2.96  0.4
# 2    Dinelson Lamet   27  3   3  15.2  ...   0.0%  1.72  2.74  4.69  0.4
# 3       Zach Davies   27  3   3  15.2  ...   9.1%  2.87  3.19  4.05  0.4
# 4  Garrett Richards   32  3   3  15.2  ...  11.8%  4.60  3.57  3.86  0.3
#
# [5 rows x 16 columns]

# %%
Chris_Paddack = padres_pitching.iloc[0,0:]

# %%
giants_pitching.head(9)
# Out:
#             Name  Age  G  GS    IP  ...  HR/FB    ERA   FIP   xFIP  WAR
# 0  Kevin Gausman   29  3   2  13.2  ...  14.3%   5.27  2.85   2.79  0.3
# 1     Drew Smyly   31  3   2   8.1  ...   0.0%   3.24  1.80   3.31  0.3
# 2     Logan Webb   23  3   3  12.2  ...   8.3%   2.13  4.10   4.78  0.1
# 3     Sam Selman   29  4   0   5.0  ...  20.0%   1.80  2.60   1.79  0.0
# 4   Conner Menez   25  6   0   8.2  ...   7.7%   2.08  4.84   6.04  0.0
# 5   Tyler Rogers   29  7   0   6.0  ...   0.0%  13.50  4.16   5.06  0.0
# 6   Johnny Cueto   34  3   3  12.2  ...  15.4%   4.97  5.21   5.00  0.0
# 7    Sam Coonrod   27  4   0   3.2  ...   0.0%   7.36  5.18   6.65  0.0
# 8   Dany Jimenez   26  2   0   1.1  ...   0.0%   6.75  8.25  10.94  0.0
#
# [9 rows x 16 columns]

# %%
Johnny_Cueto = giants_pitching.iloc[6,0:]

# %%
dodgers_pitching.head()
# Out:
#               Name  Age  G  GS    IP  ...  HR/FB   ERA   FIP  xFIP  WAR
# 0      Julio Urias   23  3   3  15.0  ...   0.0%  2.40  2.86  4.66  0.4
# 1       Dustin May   22  3   3  13.2  ...  14.3%  2.63  2.63  2.60  0.4
# 2  Clayton Kershaw   32  1   1   5.2  ...   0.0%  0.00  0.88  1.20  0.3
# 3       Jake McGee   33  6   0   5.1  ...   0.0%  0.00  0.18  1.53  0.2
# 4   Ross Stripling   30  3   3  18.0  ...  13.0%  4.00  4.22  4.35  0.2
#
# [5 rows x 16 columns]

# %%
Clayton_Kershaw = dodgers_pitching.iloc[2,0:]

# %%
Zach_Plesac.ERA + Matt_Foster.ERA
# Out:
# 1.8

# %%
Matt_Foster.ERA
# Out:
# 0.0

# %%
Framber_Valdez.ERA + Frankie_Montas.ERA
# Out:
# 4.779999999999999

# %%
Kolby_Allard.ERA + Anthony_Desclafani.ERA
# Out:
# 2.25

# %%
Ivan_Nova.ERA + Derek_Holland.ERA
# Out:
# 8.98

# %%
Tom_Eshelman.ERA + Austin_Voth.ERA
# Out:
# 6.300000000000001

# %%
Merrill_Kelly.ERA + Chris_Paddack.ERA
# Out:
# 5.279999999999999

# %%
Johnny_Cueto.ERA + Clayton_Kershaw.ERA
# Out:
# 4.97

# %%
import sklearn
import statsmodels

# %%
import ipykernel

# %%
import bisect

# %%
M_Kelly = dict(Merrill_Kelly)

# %%
M_Kelly
# Out:
# {'Age': 31,
#  'BABIP': 0.231,
#  'BB%': '1.9%',
#  'ERA': 2.63,
#  'FIP': 4.46,
#  'G': 2,
#  'GB%': '35.7%',
#  'GS': 2,
#  'HR/9': 1.98,
#  'HR/FB': '17.6%',
#  'IP': 13.2,
#  'K%': '20.4%',
#  'LOB%': '100.0%',
#  'Name': 'Merrill Kelly',
#  'WAR': 0.2,
#  'xFIP': 3.84}

# %%
dbacks_pitching.head()
# Out:
#              Name  Age  G  GS    IP     K%  ...    GB%  HR/FB   ERA   FIP  xFIP  WAR
# 0  Archie Bradley   27  3   0   3.2  43.8%  ...  12.5%   0.0%  2.45  0.00  0.98  0.3
# 1   Merrill Kelly   31  2   2  13.2  20.4%  ...  35.7%  17.6%  2.63  4.46  3.84  0.2
# 2      Zac Gallen   24  3   3  16.0  31.3%  ...  45.9%  23.1%  2.81  4.31  3.33  0.2
# 3   Junior Guerra   35  6   0   5.2  21.1%  ...  69.2%   0.0%  0.00  2.64  3.28  0.1
# 4  Taylor Widener   25  3   0   5.2  19.1%  ...  57.1%   0.0%  0.00  3.17  4.12  0.0
#
# [5 rows x 16 columns]
