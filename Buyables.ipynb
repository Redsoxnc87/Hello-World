# %% [markdown]
# <a href="https://colab.research.google.com/github/Redsoxnc87/Hello-World/blob/master/Buyables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import math 
import requests

# %%
import pandas.plotting
import operator
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import scipy.stats

# %%
sector = pd.read_csv('Multisector_Oversold_Returns.csv')

# %%
sector.describe()
# Out:
#               Last  14D Rel Str  ...   RSI_Diff      Diff_52
# count    56.000000    56.000000  ...  55.000000    56.000000
# mean    136.608750     0.491786  ...  -0.021455    82.231964
# std     395.641647     0.043237  ...   0.043776   227.239106
# min       1.590000     0.360000  ...  -0.150000     2.150000
# 25%      29.222500     0.460000  ...  -0.050000    21.142500
# 50%      65.815000     0.510000  ...  -0.010000    40.920000
# 75%     121.032500     0.520000  ...   0.010000    73.920000
# max    2986.550000     0.540000  ...   0.050000  1718.260000
#
# [8 rows x 17 columns]

# %%
L= list(range(0,56))

# %%
fl = operator.sub(sector['Last'],sector['52W Low'])
fh = operator.sub(sector['52W High'],sector['Last'])

# %%
sector['From_Low']=(fl)
sector['From_High']=(fh)

# %%
sector.describe()
# Out:
#               Last  14D Rel Str  ...     From_Low   From_High
# count    56.000000    56.000000  ...    56.000000   56.000000
# mean    136.608750     0.491786  ...    56.224286   26.007679
# std     395.641647     0.043237  ...   180.677265   48.043751
# min       1.590000     0.360000  ...     0.560000    1.060000
# 25%      29.222500     0.460000  ...     9.057500    7.022500
# 50%      65.815000     0.510000  ...    22.995000   14.605000
# 75%     121.032500     0.520000  ...    42.492500   31.747500
# max    2986.550000     0.540000  ...  1360.520000  357.740000
#
# [8 rows x 19 columns]

# %%
sector['From_Low'].hist()

# %%
twrd_low = sector.loc[(sector['From_Low'])<10]

# %%
len(twrd_low)
# Out:
# 16

# %%
twrd_low
# Out:
#    Symbol                                Name  ...  From_Low  From_High
# 1     FSS                 Federal Signal Corp  ...      6.30       6.13
# 3     CPB               Campbell Soup Company  ...      9.60       7.91
# 17   AVCO                    Avalon Globocare  ...      1.09       1.06
# 19    CBZ                            Cbiz Inc  ...      5.96       5.92
# 31    GFN                General Finance Corp  ...      1.47       5.15
# 33    HMI                      Huami Corp ADR  ...      4.90       4.78
# 34    HQI                       Hirequest Inc  ...      1.09       2.46
# 36    INS            Intelligent Systems Corp  ...      6.66      26.32
# 37   IPDN  Professional Diversity Network Inc  ...      0.56       2.05
# 38   KFRC                          Kforce Inc  ...      7.43      14.61
# 39   LUNA                Luna Innovations Inc  ...      1.32       3.75
# 42   PAYS                         Paysign Inc  ...      5.10       8.73
# ...

# %%
twrd_low.to_csv('Buyable_Stocks.csv', index=False)

# %%
gDE = sector.loc[(sector['Debt/Equity'])<0.8]

# %%
len(gDE)
# Out:
# 33

# %%
gDE.Cummulative_Returns.hist()

# %%
pos_gde = gDE.loc[(gDE['Cummulative_Returns'])>3]

# %%
len(pos_gde)
# Out:
# 8

# %%
pos_gde
# Out:
#    Symbol                      Name     Last  ...  Diff_52  From_Low  From_High
# 8    AMZN            Amazon.com Inc  2986.55  ...  1718.26   1360.52     357.74
# 26   EXPO              Exponent Inc    80.01  ...    25.51     21.98       3.53
# 27    FCN            Fti Consulting   112.77  ...    47.79     16.46      31.33
# 32    GPN       Global Payments Inc   172.63  ...   104.08     67.09      36.99
# 36    INS  Intelligent Systems Corp    29.92  ...    32.98      6.66      26.32
# 39   LUNA      Luna Innovations Inc     5.57  ...     5.07      1.32       3.75
# 41    NRC    National Research Corp    58.42  ...    37.35     24.42      12.93
# 42   PAYS               Paysign Inc     8.73  ...    13.83      5.10       8.73
#
# [8 rows x 21 columns]
