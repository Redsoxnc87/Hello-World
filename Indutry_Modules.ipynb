# %% [markdown]
# <a href="https://colab.research.google.com/github/Redsoxnc87/Hello-World/blob/master/Indutry_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tech_services_py as ts

# %%
import communications_components_py as cc

# %%
ts.techService.Nincome_Share
# Out:
# 0    -1.162195
# 1    -1.125267
# 2     3.148611
# 3     0.998583
# 4     5.894616
# 5    -1.937709
# 6    -0.656910
# 7     1.320505
# 8     0.037074
# 9     3.666327
# 10    0.138430
# 11   -1.002915
# 12   -0.420717
# Name: Nincome_Share, dtype: float64

# %%
ts.techService.head(13)
# Out:
#    Symbol  ... Sales_Mcap
# 0    SPOT  ...   0.179100
# 1    DOCU  ...   0.024769
# 2     TRI  ...   0.151212
# 3     IQV  ...   0.383147
# 4      TT  ...   0.583204
# 5    ESTC  ...   0.046589
# 6    OCFT  ...   0.044769
# 7    FUTU  ...   0.231937
# 8    SWCH  ...   0.125422
# 9    APTV  ...   0.615384
# 10    GSX  ...   0.013058
# 11   WORK  ...   0.040630
# 12    GDS  ...   0.048434
#
# [13 rows x 49 columns]

# %%
TRI = ts.techService.iloc[2,0:]

# %%
# Out:
# 79.31
