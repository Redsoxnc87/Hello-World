# %% [markdown]
# <a href="https://colab.research.google.com/github/Redsoxnc87/Hello-World/blob/master/Untitled184.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import requests 
import math

# %%
import pandas.plotting
import operator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
homes = pd.read_csv('Homebuilders.csv')
air = pd.read_csv('Airfreight_Couriers.csv')
apperal = pd.read_csv('Apperal_Footware.csv')
auto = pd.read_csv('Automotive.csv')

# %%
homes.describe()
# Out:
#               Last   Change %  ...  Basic EPS (TTM)  Number of Employees
# count    23.000000  23.000000  ...        23.000000            23.000000
# mean    228.998696  -0.537512  ...        13.302235          3569.347826
# std     856.123950   1.190441  ...        45.844422          3240.323042
# min       0.980000  -3.921569  ...         0.044300           109.000000
# 25%      21.405000  -1.020244  ...         1.503700          1295.500000
# 50%      42.790000  -0.442478  ...         3.438400          2140.000000
# 75%      69.155000   0.127720  ...         6.252200          5472.500000
# max    4151.030000   1.253918  ...       223.245600         10106.000000
#
# [8 rows x 8 columns]

# %%
air.describe()
# Out:
#              Last  Change %  ...  Basic EPS (TTM)  Number of Employees
# count    7.000000  7.000000  ...         7.000000             7.000000
# mean    95.204286  1.330310  ...         3.103386        111967.857143
# std     68.682331  2.031760  ...         1.707190        190569.941649
# min      5.400000  0.218764  ...         0.208200           708.000000
# 25%     55.105000  0.409843  ...         2.244500          4820.000000
# 50%     87.170000  0.494945  ...         3.448800         15427.000000
# 75%    127.885000  0.948212  ...         4.254600        131500.000000
# max    207.880000  5.882353  ...         5.068500        495000.000000
#
# [8 rows x 8 columns]

# %%
apperal.describe()
# Out:
#              Last   Change %  ...  Basic EPS (TTM)  Number of Employees
# count   18.000000  18.000000  ...        18.000000            17.000000
# mean    56.213889  -1.242520  ...         1.791803         18620.705882
# std     80.745379   1.548107  ...         2.259940         25293.806104
# min      4.440000  -4.937122  ...         0.085800           768.000000
# 25%     16.937500  -1.734180  ...         0.733075          3400.000000
# 50%     22.600000  -1.002307  ...         1.265900          4000.000000
# 75%     55.805000  -0.136364  ...         1.904875         15100.000000
# max    311.000000   1.327475  ...        10.227300         75400.000000
#
# [8 rows x 8 columns]

# %%
auto.describe()
# Out:
#              Last   Change %  ...  Basic EPS (TTM)  Number of Employees
# count   18.000000  18.000000  ...        18.000000            17.000000
# mean    42.415311   0.307309  ...         2.039175         39802.764706
# std     36.196382   5.869330  ...         1.960729         55025.798076
# min      0.030700  -5.633803  ...         0.002700            16.000000
# 25%     15.907500  -1.320242  ...         0.611825          4200.000000
# 50%     33.095000  -1.023969  ...         1.718100          9100.000000
# 75%     64.860000   0.147885  ...         2.446975         51000.000000
# max    113.610000  22.800000  ...         6.584600        164100.000000
#
# [8 rows x 8 columns]

# %%
homes.head()
# Out:
#   Ticker   Last  Change %  ...             Sector Exchange      Industry
# 0    MHO  45.51 -0.654879  ...  Consumer Durables     NYSE  Homebuilding
# 1    CCS  38.25 -0.442478  ...  Consumer Durables     NYSE  Homebuilding
# 2  LEN.B  60.21 -0.099552  ...  Consumer Durables     NYSE  Homebuilding
# 3    TPH  18.02 -0.166205  ...  Consumer Durables     NYSE  Homebuilding
# 4   GRBK  15.56  0.193174  ...  Consumer Durables   NASDAQ  Homebuilding
#
# [5 rows x 13 columns]

# %%
MV = operator.truediv(homes['Market Capitalization'],homes['Volume'])

# %%
homes['Mcap_by_Vol']=(MV)

# %%
PB = operator.truediv(homes['PE Ratio (TTM)'],homes['Basic EPS (TTM)'])

# %%
homes['PE_by_EPS']=(PB)

# %%
homes.describe()
# Out:
#               Last   Change %  ...    Mcap_by_Vol   PE_by_EPS
# count    23.000000  23.000000  ...      23.000000   23.000000
# mean    228.998696  -0.537512  ...   48973.336967   30.135385
# std     856.123950   1.190441  ...  177267.630449  107.247296
# min       0.980000  -3.921569  ...     140.357849    0.090396
# 25%      21.405000  -1.020244  ...    3257.563697    1.844334
# 50%      42.790000  -0.442478  ...    6020.690733    3.495962
# 75%      69.155000   0.127720  ...   13181.054957   10.744729
# max    4151.030000   1.253918  ...  857486.579367  519.747871
#
# [8 rows x 10 columns]

# %%
homes.Volume.hist()

# %%
homes.to_csv('Hbuilders.csv',index=False)

# %%
auto.to_csv('Autoparts.csv', index=False)

# %%
air.to_csv('Afreight.csv', index=False)

# %%
homes
# Out:
#    Ticker     Last  Change %  ...      Industry    Mcap_by_Vol   PE_by_EPS
# 0     MHO    45.51 -0.654879  ...  Homebuilding    8121.255844    1.361890
# 1     CCS    38.25 -0.442478  ...  Homebuilding    4766.667974    1.939763
# 2   LEN.B    60.21 -0.099552  ...  Homebuilding   85245.500372    1.365900
# 3     TPH    18.02 -0.166205  ...  Homebuilding    2180.611079    4.672093
# 4    GRBK    15.56  0.193174  ...  Homebuilding    2904.919036    6.032062
# 5     PHM    46.17 -0.944003  ...  Homebuilding    6180.098678    2.582555
# 6     MDC    44.90 -2.306353  ...  Homebuilding    6006.935679    2.676678
# 7    CHCI     3.23  1.253918  ...  Homebuilding     201.851823   41.593433
# 8     LEN    76.81 -0.466503  ...  Homebuilding   14003.801519    1.748906
# 9     KBH    36.99 -1.596169  ...  Homebuilding    3082.330324    3.458263
# 10    MTH   102.88 -0.637435  ...  Homebuilding   16774.989507    1.359624
# ...
